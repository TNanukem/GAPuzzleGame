# %%
import time
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('results.txt', sep=' ').iloc[:, :3]
results.columns = ['generation', 'avg_fitness', 'max_fitness']

# %%
n_mov = results.iloc[-1, 1]
n_mov
# Out:
# 226.0

# %%
initial_pop = [10, 100, 500, 1000, 5000]
initial_chromosome = [2, 4, 8, 12, 16, 32]
mutation_prob = [0.001, 0.004, 0.01, 0.02, 0.1]
crossover_prob = [0.01, 0.04, 0.1, 0.2]

final_df = pd.DataFrame()

for pop in initial_pop:
    for chrom in initial_chromosome:
        for mutation in mutation_prob:
            for crossover in crossover_prob:
                for rept in range(0,10):
                    exec = './main puzzles/puzzle1.txt {} {} {} {}'.format(pop, chrom, crossover, mutation)
                    print(exec)

                    start = time.time()
                    a = subprocess.getoutput(exec)
                    end = time.time()

                    results = pd.read_csv('results.txt', sep=' ').iloc[:, :3]
                    results.columns = ['generation', 'avg_fitness', 'max_fitness']
                    final_df = final_df.append({'n_steps': results.iloc[-1, 1], 'n_generations': len(results)-1, 'pop_size': pop, 
                                    'choromosome_size': chrom, 'mutation_prob': mutation, 'crossover_prob': crossover,
                                    'avg_fitness': list(results['avg_fitness']), 'max_fitness': list(results['max_fitness']), 
                                    'time': end-start}, ignore_index=True)
final_df
# Out:
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.04 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.1 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.2 0.001
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.04 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.1 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.2 0.004
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.04 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.1 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.2 0.01
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.01 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02
# ./main puzzles/puzzle1.txt 10 2 0.04 0.02

# %%
final_df.to_csv('final_df_with_time.csv', sep=';', index=False)

# %% [markdown]
# # Analysis

# %%
final_df
# Out:
#                       avg_fitness  choromosome_size  crossover_prob  \
# 0     [0.0642, 0.0652, inf, 18.0]               2.0            0.01
# 1     [0.0642, 0.0652, inf, 18.0]               2.0            0.01
# 2     [0.0642, 0.0652, inf, 18.0]               2.0            0.01
# 3     [0.0642, 0.0652, inf, 18.0]               2.0            0.01
# 4     [0.0642, 0.0652, inf, 18.0]               2.0            0.01
# ...                           ...               ...             ...
# 1165  [0.0642, 0.0652, inf, 18.0]               4.0            0.01
# 1166  [0.0642, 0.0652, inf, 18.0]               4.0            0.01
# 1167  [0.0642, 0.0652, inf, 18.0]               4.0            0.01
# 1168  [0.0642, 0.0652, inf, 18.0]               4.0            0.01
# 1169  [0.0642, 0.0652, inf, 18.0]               4.0            0.01
#
#                                max_fitness  mutation_prob  n_generations  \
# 0     [0.16699999999999998, 0.5, inf, nan]           0.01            3.0
# 1     [0.16699999999999998, 0.5, inf, nan]           0.01            3.0
# 2     [0.16699999999999998, 0.5, inf, nan]           0.01            3.0
# 3     [0.16699999999999998, 0.5, inf, nan]           0.01            3.0
# 4     [0.16699999999999998, 0.5, inf, nan]           0.01            3.0
# ...                                    ...            ...            ...
# 1165  [0.16699999999999998, 0.5, inf, nan]           0.04            3.0
# 1166  [0.16699999999999998, 0.5, inf, nan]           0.04            3.0
# 1167  [0.16699999999999998, 0.5, inf, nan]           0.04            3.0
# 1168  [0.16699999999999998, 0.5, inf, nan]           0.04            3.0
# 1169  [0.16699999999999998, 0.5, inf, nan]           0.04            3.0
#
#       n_steps  pop_size      time
# 0        18.0      10.0  1.019672
# 1        18.0      10.0  1.077365
# 2        18.0      10.0  0.663080
# 3        18.0      10.0  0.882843
# 4        18.0      10.0  0.928951
# ...       ...       ...       ...
# 1165     18.0     100.0  0.833978
# 1166     18.0     100.0  0.925922
# 1167     18.0     100.0  3.711813
# 1168     18.0     100.0  1.201288
# 1169     18.0     100.0  1.356704
#
# [1170 rows x 9 columns]
